# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder

# %%
# %cd /content/drive
# Out:
# /content/drive

# %%
df = pd.read_csv('/content/drive/MyDrive/train.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
missing = df.isnull().sum()
missing = missing[missing > 0]
missing.sort_values(inplace=True)
missing.plot.bar()
# Out:
# <Axes: >

# %%
df.drop(["PoolQC","Fence","MiscFeature","Alley"],axis=1,inplace=True)

# %%
for i in df.columns:
  df[i].fillna(df[i].mode()[0],inplace=True)

# %%
cat_columns = df.select_dtypes(include=['object']).columns
label_encoder = LabelEncoder()
df[cat_columns] = df[cat_columns].apply(lambda item: label_encoder.fit_transform(item))

# %%
df
# Out:
#         Id  MSSubClass  MSZoning  LotFrontage  LotArea  Street  LotShape  \
# 0        1          60         3         65.0     8450       1         3
# 1        2          20         3         80.0     9600       1         3
# 2        3          60         3         68.0    11250       1         0
# 3        4          70         3         60.0     9550       1         0
# 4        5          60         3         84.0    14260       1         0
# ...    ...         ...       ...          ...      ...     ...       ...
# 1455  1456          60         3         62.0     7917       1         3
# 1456  1457          20         3         85.0    13175       1         3
# 1457  1458          70         3         66.0     9042       1         3
# 1458  1459          20         3         68.0     9717       1         3
# 1459  1460          20         3         75.0     9937       1         3
#
#       LandContour  Utilities  LotConfig  ...  EnclosedPorch  3SsnPorch  \
# ...

# %%
from sklearn.ensemble import RandomForestRegressor
model = RandomForestRegressor(n_estimators=300, random_state=0)
model.fit(df[df.columns[:-1]],df[df.columns[-1]])
# Out:
# RandomForestRegressor(n_estimators=300, random_state=0)

# %%
test_df = pd.read_csv('/content/drive/MyDrive/test.csv')

# %%
test_df.drop(["PoolQC","Fence","MiscFeature","Alley"],axis=1,inplace=True)

# %%
test_df
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0     1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1     1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2     1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3     1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4     1465         120       RL         43.0     5005   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1454  2915         160       RM         21.0     1936   Pave   NaN      Reg
# 1455  2916         160       RM         21.0     1894   Pave   NaN      Reg
# 1456  2917          20       RL        160.0    20000   Pave   NaN      Reg
# 1457  2918          85       RL         62.0    10441   Pave   NaN      Reg
# 1458  2919          60       RL         74.0     9627   Pave   NaN      Reg
#
# ...

# %%
for i in test_df.columns:
  test_df[i].fillna(test_df[i].mode()[0],inplace=True)

# %%
test_df[cat_columns] = test_df[cat_columns].apply(lambda item: label_encoder.fit_transform(item))

# %%
test_df
# Out:
#         Id  MSSubClass  MSZoning  LotFrontage  LotArea  Street  LotShape  \
# 0     1461          20         2         80.0    11622       1         3
# 1     1462          20         3         81.0    14267       1         0
# 2     1463          60         3         74.0    13830       1         0
# 3     1464          60         3         78.0     9978       1         0
# 4     1465         120         3         43.0     5005       1         0
# ...    ...         ...       ...          ...      ...     ...       ...
# 1454  2915         160         4         21.0     1936       1         3
# 1455  2916         160         4         21.0     1894       1         3
# 1456  2917          20         3        160.0    20000       1         3
# 1457  2918          85         3         62.0    10441       1         3
# 1458  2919          60         3         74.0     9627       1         3
#
#       LandContour  Utilities  LotConfig  ...  OpenPorchSF  EnclosedPorch  \
# ...

# %%
predicted_df = pd.DataFrame()

# %%
predicted_df['Id'] = test_df['Id']

# %%
predicted_df['SalePrice'] = model.predict(test_df)

# %%
predicted_df
# Out:
#         Id      SalePrice
# 0     1461  126083.902000
# 1     1462  153852.568000
# 2     1463  179569.268333
# 3     1464  180980.688667
# 4     1465  198461.006000
# ...    ...            ...
# 1454  2915   84721.874000
# 1455  2916   85496.068667
# 1456  2917  151814.345333
# 1457  2918  114108.135667
# 1458  2919  228589.495333
#
# [1459 rows x 2 columns]

# %%
predicted_df.to_csv('out.csv',index = False)

# %%
predicted_df.to_csv('submission.csv')
